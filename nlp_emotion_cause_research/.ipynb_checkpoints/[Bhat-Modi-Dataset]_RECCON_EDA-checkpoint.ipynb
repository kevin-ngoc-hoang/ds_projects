# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = './data/RECCON/original_annotation'

# %%
# Dataset doesn't provide an explicit "train" set, we can attempt to partition the existing data
df_train = pd.read_json(f'{DATA_PATH}/dailydialog_train.json')
df_valid = pd.read_json(f'{DATA_PATH}/dailydialog_valid.json')
df_test = pd.read_json(f'{DATA_PATH}/dailydialog_test.json')

# %%
df_train
# Out:
#                                              tr_4466  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Hey...
#
#                                              tr_7536  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Ann...
#
#                                               tr_754  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Wha...
#
#                                              tr_4110  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Oh ...
#
#                                              tr_3432  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Hav...
#
#                                               tr_943  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'how...
#
#                                              tr_3894  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'My ...
#
#                                              tr_1561  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'You...
#
#                                              tr_4533  \
# ...

# %%
df_valid
# Out:
#                                               va_980  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Mr ...
#
#                                               va_345  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'I c...
#
#                                              tr_7727  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Exc...
#
#                                               va_184  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Hel...
#
#                                              tr_7853  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Yea...
#
#                                               va_371  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Ahe...
#
#                                               va_838  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Wha...
#
#                                              tr_7729  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'All...
#
#                                               va_829  \
# ...

# %%
df_test
# Out:
#                                              tr_9708  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'The...
#
#                                               te_935  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'I'm...
#
#                                               te_665  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Hi ...
#
#                                              tr_9573  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Can...
#
#                                             tr_10180  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Joh...
#
#                                              tr_9306  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'It'...
#
#                                               te_416  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Yes...
#
#                                               te_501  \
# 0  [{'turn': 1, 'speaker': 'A', 'utterance': 'Thi...
#
#                                              tr_8938  \
# ...

# %%
first_ex = df_train.iloc[0]

# %%
first_ex_dict = dict(first_ex)
first_ex_dict
# Out:
# {'tr_4466': [{'turn': 1,
#    'speaker': 'A',
#    'utterance': 'Hey , you wanna see a movie tomorrow ?',
#    'emotion': 'happiness',
#    'expanded emotion cause evidence': [1],
#    'expanded emotion cause span': ['see a movie tomorrow ?'],
#    'type': ['no-context']},
#   {'turn': 2,
#    'speaker': 'B',
#    'utterance': 'Sounds like a good plan . What do you want to see ?',
#    'emotion': 'happiness',
#    'expanded emotion cause evidence': [1],
#    'expanded emotion cause span': ['see a movie tomorrow ?'],
#    'type': ['inter-personal']},
#   {'turn': 3,
#    'speaker': 'A',
#    'utterance': 'How about Legally Blonde .',
#    'emotion': 'neutral'},
#   {'turn': 4,
#    'speaker': 'B',
#    'utterance': "Ah , my girlfriend wanted to see that movie . I have to take her later so I don't want to watch it ahead of time . How about The Cube ?",
#    'emotion': 'neutral'},
#   {'turn': 5,
#    'speaker': 'A',
#    'utterance': "Isn't that a scary movie ?",
# ...

# %%
# First key in dictionary
first_ex_dict['tr_4466']
# Out:
# [{'turn': 1,
#   'speaker': 'A',
#   'utterance': 'Hey , you wanna see a movie tomorrow ?',
#   'emotion': 'happiness',
#   'expanded emotion cause evidence': [1],
#   'expanded emotion cause span': ['see a movie tomorrow ?'],
#   'type': ['no-context']},
#  {'turn': 2,
#   'speaker': 'B',
#   'utterance': 'Sounds like a good plan . What do you want to see ?',
#   'emotion': 'happiness',
#   'expanded emotion cause evidence': [1],
#   'expanded emotion cause span': ['see a movie tomorrow ?'],
#   'type': ['inter-personal']},
#  {'turn': 3,
#   'speaker': 'A',
#   'utterance': 'How about Legally Blonde .',
#   'emotion': 'neutral'},
#  {'turn': 4,
#   'speaker': 'B',
#   'utterance': "Ah , my girlfriend wanted to see that movie . I have to take her later so I don't want to watch it ahead of time . How about The Cube ?",
#   'emotion': 'neutral'},
#  {'turn': 5,
#   'speaker': 'A',
#   'utterance': "Isn't that a scary movie ?",
#   'emotion': 'neutral'},
#  {'turn': 6,
# ...
